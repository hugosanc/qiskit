# %%
from qiskit import *
from qiskit.visualization import plot_histogram
from math import *

qc = QuantumCircuit(1)
vector = [1/sqrt(2), 1/sqrt(2)]
qc.initialize(vector,0)
qc.draw()
# Out:
#         ┌─────────────────────────────┐
# q_0: |0>┤ Initialize(0.70711,0.70711) ├
#         └─────────────────────────────┘

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
# plot_histogram(result.get_counts(qc))
print(result.get_statevector())
# Out:
# [0.70710678+0.j 0.70710678+0.j]

# %%
from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(1)
vector = [1/sqrt(2), 1/sqrt(2)]
qc.initialize(vector,0)
qc.rz(pi/4, 0)
qc.draw()
# Out:
#         ┌─────────────────────────────┐┌──────────┐
# q_0: |0>┤ Initialize(0.70711,0.70711) ├┤ Rz(pi/4) ├
#         └─────────────────────────────┘└──────────┘

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
print(result.get_statevector())
# Out:
# [0.70710678+0.j  0.5       +0.5j]

# %%
from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(1)
vector = [1/sqrt(2), 1/sqrt(2)]
qc.initialize(vector,0)
qc.s(0)
qc.draw()
# Out:
#         ┌─────────────────────────────┐┌───┐
# q_0: |0>┤ Initialize(0.70711,0.70711) ├┤ S ├
#         └─────────────────────────────┘└───┘

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
print(result.get_statevector())
# Out:
# [0.70710678+0.j         0.        +0.70710678j]

# %%
from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(1)
vector = [1/sqrt(2), 1/sqrt(2)]
qc.initialize(vector,0)
qc.sdg(0)
# qc.s(0)
qc.draw()
# Out:
#         ┌─────────────────────────────┐┌─────┐
# q_0: |0>┤ Initialize(0.70711,0.70711) ├┤ Sdg ├
#         └─────────────────────────────┘└─────┘

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
print(result.get_statevector())
# Out:
# [0.70710678+0.j         0.        -0.70710678j]

# %%
from qiskit.tools.visualization import plot_bloch_multivector
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(1)
vector = [1/sqrt(2),1/sqrt(2)]
qc.initialize(vector,0)
qc.t(0)
qc.draw()
# Out:
#         ┌─────────────────────────────┐┌───┐
# q_0: |0>┤ Initialize(0.70711,0.70711) ├┤ T ├
#         └─────────────────────────────┘└───┘

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
print(result.get_statevector())
# Out:
# [0.70710678+0.j  0.5       +0.5j]

# %%
plot_bloch_multivector(result.get_statevector(qc))

# %%
qc = QuantumCircuit(1)
vector = [1/sqrt(2),1/sqrt(2)]
qc.initialize(vector,0)
# qc.t(0)
qc.tdg(0)
qc.draw()
# Out:
#         ┌─────────────────────────────┐┌─────┐
# q_0: |0>┤ Initialize(0.70711,0.70711) ├┤ Tdg ├
#         └─────────────────────────────┘└─────┘

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc, simulator).result()
print(result.get_statevector())
# Out:
# [0.70710678+0.j  0.5       -0.5j]

# %%
plot_bloch_multivector(result.get_statevector(qc))
