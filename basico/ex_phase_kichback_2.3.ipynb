# %%
from qiskit import *
from math import *
from qiskit.visualization import plot_histogram, plot_bloch_multivector

qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.cx(0,1)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,simulator).result()

plot_histogram(result.get_counts())
print(result.get_statevector(qc,3))
# Out:
# [0.5+0.j 0.5+0.j 0.5+0.j 0.5+0.j]

# %%
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.z(1)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,simulator).result()

plot_histogram(result.get_counts())
print(result.get_statevector())
# Out:
# [ 0.5+0.j  0.5+0.j -0.5+0.j -0.5+0.j]

# %%
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.z(1)
qc.cx(0,1)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,simulator).result()

plot_histogram(result.get_counts())
print(result.get_statevector())
# Out:
# [ 0.5+0.j -0.5+0.j -0.5+0.j  0.5+0.j]

# %%
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.h(1)
qc.cx(0,1)
qc.h(0)
qc.h(1)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('unitary_simulator')
result = execute(qc,simulator).result()

print(result.get_unitary())
# Out:
# [[ 1.00000000e+00-1.22464680e-16j  1.60753511e-32+6.12323400e-17j
#   -7.85046229e-17+3.08148791e-32j  1.11022302e-16+6.12323400e-17j]
#  [ 9.91237528e-33+6.12323400e-17j  1.00000000e+00-2.44929360e-16j
#    1.11022302e-16+6.12323400e-17j -7.85046229e-17+2.46519033e-32j]
#  [-1.11022302e-16+6.12323400e-17j  7.85046229e-17-3.69778549e-32j
#    1.57009246e-16+6.12323400e-17j  1.00000000e+00-3.67394040e-16j]
#  [ 7.85046229e-17-1.84889275e-32j -1.11022302e-16+6.12323400e-17j
#    1.00000000e+00-2.44929360e-16j -1.57009246e-16+6.12323400e-17j]]

# %%
qc = QuantumCircuit(2)
qc.cx(0,1)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('unitary_simulator')
result = execute(qc,simulator).result()

print(result.get_unitary())
# Out:
# [[1.+0.j 0.+0.j 0.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j 0.+0.j 1.+0.j]
#  [0.+0.j 0.+0.j 1.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j 0.+0.j 0.+0.j]]

# %%
qc = QuantumCircuit(2)
qc.cu1(pi/4, 0, 1)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('unitary_simulator')
result = execute(qc,simulator).result()

print(result.get_unitary())
# Out:
# [[1.        +0.j         0.        +0.j         0.        +0.j
#   0.        +0.j        ]
#  [0.        +0.j         1.        +0.j         0.        +0.j
#   0.        +0.j        ]
#  [0.        +0.j         0.        +0.j         1.        +0.j
#   0.        +0.j        ]
#  [0.        +0.j         0.        +0.j         0.        +0.j
#   0.70710678+0.70710678j]]

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,simulator).result()

plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.x(1)
qc.draw('mpl')

# %%
result = execute(qc,simulator).result()
plot_bloch_multivector(result.get_statevector())

# %%
qc.cu1(pi/4, 0, 1)
qc.draw('mpl')

# %%
result = execute(qc,simulator).result()
plot_bloch_multivector(result.get_statevector())

# %%
simulator = Aer.get_backend('unitary_simulator')
result = execute(qc,simulator).result()

print(result.get_unitary())
# Out:
# [[ 0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.70710678+0.00000000e+00j  0.70710678-8.65956056e-17j]
#  [ 0.        +0.00000000e+00j  0.        +0.00000000e+00j
#    0.70710678+0.00000000e+00j -0.70710678+8.65956056e-17j]
#  [ 0.70710678+0.00000000e+00j  0.70710678-8.65956056e-17j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j]
#  [ 0.5       +5.00000000e-01j -0.5       -5.00000000e-01j
#    0.        +0.00000000e+00j  0.        +0.00000000e+00j]]

# %%
qc = QuantumCircuit(3)
theta = pi/2
qc.cx(0,2)
qc.cx(0,1)
qc.rx(theta,0)
qc.cx(0,1)
qc.cx(0,1)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,simulator).result()

plot_histogram(result.get_counts())

# %%
plot_bloch_multivector(result.get_statevector())

# %%
qc = QuantumCircuit(3)
qc.h(0)
qc.h(1)
qc.h(2)
qc.cx(0,2)
qc.cx(0,1)
qc.rx(theta,0)
qc.cx(0,1)
qc.cx(0,1)
qc.h(2)
qc.h(1)
qc.h(0)
qc.draw('mpl')

# %%
simulator = Aer.get_backend('statevector_simulator')
result = execute(qc,simulator).result()

plot_histogram(result.get_counts())

# %%
plot_bloch_multivector(result.get_statevector())
